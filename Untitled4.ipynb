# %% [markdown]
# <a href="https://colab.research.google.com/github/PASUPULETIMANASA/Manasa/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install PYPDF2
# Out:
# Collecting PYPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: PYPDF2
# Successfully installed PYPDF2-3.0.1

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)

# %%
pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.54.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.10.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.1)

# %%
import os
import openai
import PyPDF2
from transformers import AutoTokenizer, AutoModel, AutoModelForCausalLM
import numpy as np

# Load API key from environment variable
openai.api_key = os.getenv("OPENAI_API_KEY")

# Initialize the embedding model
model_name = "sentence-transformers/all-MiniLM-L6-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# Ensure pad_token is set if not already
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token  # Set eos_token as pad_token

# Function to generate sentence embeddings
def encode_text(text):
    # Tokenize the input text, set padding=True to automatically pad the sequence
    inputs = tokenizer(
        text,
        return_tensors="pt",
        truncation=True,
        padding=True,
        return_attention_mask=True
    )

    # Get the model output (embedding) and return the mean of the last hidden state
    outputs = model(**inputs)

    # Return the embeddings by averaging the last hidden states
    embeddings = outputs.last_hidden_state.mean(dim=1).detach().numpy()

    return embeddings.flatten()  # Ensure embedding is a 1D array

# List to store chunks and their metadata
chunk_store = []

# Function to extract text from a PDF file
def extract_text_from_pdf(pdf_file):
    pdf_reader = PyPDF2.PdfReader(pdf_file)
    text_chunks = []
    for page in pdf_reader.pages:
        text = page.extract_text()
        if text:
            text_chunks.append(text)
    return text_chunks

# Function to chunk text into smaller parts
def chunk_text(text, chunk_size=500):
    words = text.split()
    chunks = [' '.join(words[i:i + chunk_size]) for i in range(0, len(words), chunk_size)]
    return chunks

# Function to create embeddings and store them in the chunk_store
def create_embeddings_and_store(pdf_chunks, metadata):
    for chunk in pdf_chunks:
        embedding = encode_text(chunk)
        chunk_store.append({"embedding": embedding, "text": chunk, "metadata": metadata})

# Function to retrieve relevant chunks based on a user query
def retrieve_relevant_chunks(query, top_k=3):
    query_embedding = encode_text(query)

    # Calculate cosine similarity
    similarities = [
        np.dot(query_embedding, entry["embedding"]) / (
            np.linalg.norm(query_embedding) * np.linalg.norm(entry["embedding"])
        ) for entry in chunk_store
    ]

    sorted_indices = np.argsort(similarities)[-top_k:][::-1]
    results = [chunk_store[idx] for idx in sorted_indices]
    return results

# Function to generate a response using a local Hugging Face model (e.g., GPT-2)
def generate_response(relevant_chunks, query):
    model_name = "gpt2"  # Replace with a better model if needed
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(model_name)

    # Prepare the input context and query
    context = "\n".join([chunk['text'] for chunk in relevant_chunks])
    prompt = f"Context: {context}\n\nQuery: {query}\n\nAnswer:"

    # Tokenize the prompt
    inputs = tokenizer.encode(prompt, return_tensors="pt", truncation=True, max_length=1024)

    # Generate the response with adjusted max_new_tokens and higher temperature for diversity
    outputs = model.generate(
        inputs,
        max_new_tokens=100,  # Limiting new tokens to avoid overly long output
        num_return_sequences=1,
        temperature=1.0,  # Increase randomness
        top_p=0.95,  # Use nucleus sampling for more variability
        do_sample=True,  # Enable sampling for randomness
    )

    # Decode and return the response
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response

# Example: Processing a PDF and handling queries
pdf_path = "/content/ManuInternshipReport.pdf"  # Replace with your PDF file
pdf_chunks = []

# Extract text from the PDF and chunk it
text_data = extract_text_from_pdf(pdf_path)
for page_text in text_data:
    pdf_chunks.extend(chunk_text(page_text))

# Store embeddings in the list
metadata = {"source": pdf_path}
create_embeddings_and_store(pdf_chunks, metadata)

# Example queries
query_1 = "What is the internship?"
relevant_chunks_1 = retrieve_relevant_chunks(query_1)
response_1 = generate_response(relevant_chunks_1, query_1)
print("Response 1:", response_1)

query_2 = "What is GUI?"
relevant_chunks_2 = retrieve_relevant_chunks(query_2)
response_2 = generate_response(relevant_chunks_2, query_2)
print("Response 2:", response_2)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Response 1: Context: INTERNSHIP COMPLETION CERTIFICATE
# SREE VIDYANIKETHAN ENGINEERING COLLEGE (AUTONOMOUS) Sree Sainath Nagar, A. Rangampet DEPARTMENT OF COMPUTER SCIENCE AND ENGINEERING Certificate This is to certify that the internship report entitled “Web Developement Virtual Internship” is the bonafide work done by Pasupuleti Manasa (Roll No: 22125A320 7) in the Department of Computer Science and Engineering , and submitted to Jawaharlal Nehru Technological University Anantapur, Anantapuramu in partial fulfillment of the requirements for the award of the degree of Bachelor of Technology in Computer Science during the academic year 2024 -2025. Head: Dr. B. Narendra Kumar Rao Professor & Head Dept. of CSE ` INTERNAL EXAMINER EXTERNALEXAMINER
# Additionally, the feedback from mentors provided valuable guidance on industry standards, helping me understand the expectations and responsibilities of a full -stack developer. The internship emphasized the importance of writing clean, maintainable code, t esting thoroughly, and documenting each step, all of which are critical skills for a career in software development. The Web Developer Virtual Internship was a comprehensive and enriching learning experience. It not only equipped me with technical skills but also shaped my approach to problem - solving, collaboration, and project management. I gained a solid foundation in full -stack development and practical experience in building a fully functional web application. This experience has prepared me well for future roles in web development, providing a strong foundation to further enhance my skills and pursue my career goals confidently.
#
# Query: What is the internship?
#
# Answer: This is a full-time working internship offered to students, to employees, and to a select group of interested professional organizations. It offers the opportunity to attend seminars and discussions, to meet with representatives, and to participate in a wide variety of programming activities.
#
# Application Deadline:
#
# October 24, 2016
#
# Full-Time Programmer: Full-Time Web Developer Internship
#
# Full-Time Analyst: Full-Time Senior Manager of Web Development
#
# Senior Analyst: Full-Time
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Response 2: Context: Responsive User Interface: The front -end design is developed using HTML, CSS, and JavaScript. CSS media queries ensure that the application adapts to various screen sizes, offering a seamless experience on both desktop and mobile. Secure and Persistent Data Storage : The application uses MySQL to store all user tasks. Each task is assigned a unique identifier, allowing for precise retrieval and manipulation. Additionally, user sessions are managed securely to prevent unauthorized access. Technical Details Front -End: The interface is built with HTML and CSS for layout and styling, with JavaScript used to add dynamic elements and improve user interaction. Key features, such as the task completion toggle and delete button, use JavaScript to update the UI instantly withou t needing a page refresh. Back -End: PHP is used to handle server -side processes, including form submissions and CRUD operations (Create, Read, Update, Delete) on the task data. The back -end logic ensures data validation, session management, and secure database connections. Database : MySQL is used for data persistence. The database schema consists of a single table for storing tasks, with fields such as task ID, title, description, status (completed or pending), and timestamp. SQL queries are optimized for efficient data retrieval and manipulation. Version Control with Git: Git was used to track the development process, allowing for versioning and easy management of code changes. This was particularly useful in testing new features while maintaining stable versions of the application. User Interface The To -Do application features a clean and minimalistic design, focusing on ease of use. The task list is prominently displayed on the main page, where users can quickly view, add, and manage .
# Front – End Development: Front - End development refers to the process of creating the user interface and user experience of a website or web application. It involves designing and implementing the visual elements that users interact with, as well as ensuring the responsiveness an d functionality of the user interface. Front -end developers, also known as client -side developers, use a combination of programming languages (such as HTML, CSS, and JavaScript) and frameworks to build the structure, layout, and behavior of a website or we b application. Here's a brief overview of the responsibilities involved in front -end development. Fig 1.1.2: Front – End Development Responsibilities: 1. User Interface (UI): Designing and implementing the user interface, including layout, navigation, and aesthetics. 2. User Experience (UX): Ensuring a smooth and engaging user experience by optimizing the performance and responsiveness of the website. 3. Interactivity: Implementing client -side scripting to enable user interactions and dynamic content updates.
# Fig 1.4.2: PHP and MYSQL Through assignments and projects, including the development of a To -Do application, I learned how to use PHP to handle back -end processes, such as processing user input, handling requests, and managing session data. MySQL was used to store and retrieve data, allow ing me to maintain user -specific task lists efficiently. Integrating PHP with MySQL taught me how to work with CRUD operations (Create, Read, Update, Delete) and how to structure data for optimized storage and retrieval. This combination of technologies proved invaluable in managing data in my To -Do application, providing real -world experience in server -client interaction. Version Control with Git: The program also introduces version control with Git, an essential tool for developers to track changes, collaborate, and maintain organized codebases. Git provides the ability to manage multiple versions of code, allowing for easy rollbacks and collaborat ive contributions. By using Git, I gained experience in managing source code repositories and learned the importance of commits, branches, and merges in the software development process. This was especially useful in the To -Do application project, as it al lowed me to experiment with new features while preserving stable versions of the code. Advanced Front -end Frameworks and Libraries: Beyond the basics of HTML, CSS, and JavaScript, the program briefly touches on advanced frameworks and libraries that can further enhance the front -end experience. Although not covered in depth, I was introduced to popular tools such as React.js, which off ers a component -based approach to building user interfaces. This exposure has prepared me to explore
#
# Query: What is GUI?
#
# Answer: A GUI is a web application that offers a graphical interface for performing the actions of the user on a particular page. It may be a webpage, the user's name, or even a browser document. The user's browser is responsible for interpreting the actions of the page, and allowing the browser to manage the user's interactions.
#
# Fully Functional Front-end Design: In order for the front -end concept to be functional, the front -end design need to be in an intuitive, functional
